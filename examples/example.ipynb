# %%
import matplotlib.pyplot as plt
import patchyAnalysisTools.trajectory as trj

# %%
# load trajectory
traj = trj.trajectory(file_name="trajectory.conf")

# get last frame
last_frame = traj.get_last_frame()

# calculate g(r)
r,gr = last_frame.calculate_rdf()

# calculate and plot s(q)
k,sk = last_frame.calculate_sq()

# position autocorr
times, corr_vals = traj.position_autocorrelation()

# %%
# plot radial distribution function
plt.plot(r*50,gr)
plt.xlabel('r (A)')
plt.ylabel('g(r)')
plt.title('radial distribution function')
plt.show()

# %%
# plot s(q)
plt.loglog(k/50,sk)
plt.xlabel('q (A^{-1}')
plt.ylabel('s(q)')
plt.show()

# %%
# plot position autocorr
plt.loglog(times, corr_vals)
plt.show()
